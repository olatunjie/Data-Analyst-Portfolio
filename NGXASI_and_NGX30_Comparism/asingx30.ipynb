# %%
# importing the required module
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_excel('C:\\NGXASINGX30.xlsx')

# %%
dataset.head()
# Out:
#      ON_DATE  NGXASI  NGX30
# 0 2022-01-04    0.75   1.10
# 1 2022-01-05    1.02  -0.99
# 2 2022-01-06    0.30  -0.08
# 3 2022-01-07    0.57   0.25
# 4 2022-01-10    0.10  -0.48

# %%
dataset.shape
# Out:
# (66, 4)

# %%
sns.lineplot(x="ON_DATE", y="NGXASI", data=dataset,label="ASI")
sns.lineplot(x="ON_DATE", y="NGX30", data=dataset,label="NGX30")
# Out:
# <AxesSubplot:xlabel='ON_DATE', ylabel='NGXASI'>

# %%
dataset.shape
# Out:
# (33, 3)
